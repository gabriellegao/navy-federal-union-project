# %%
from relevance import load_lda_model
import pandas, numpy

# %%
lda, feature_sets = load_lda_model()
df = pandas.DataFrame(data=numpy.array(lda.topics).T, columns=["topic"+str(e) for e in list(range(len(lda.topics)))])
df
# Out:
#                       topic0                  topic1  \
# 0                   be rare,                go navy!
# 1         out bit.ly/2nlpavi         @navyfederal go
# 2                struggle to                      go
# 3     @huntington_bank @usaa              where's my
# 4             bit.ly/2nlpavi                 where's
# 5                   marketer                   irish
# 6  bit.ly/2nlpavi @forrester                 @canada
# 7            rare, financial                 a proud
# 8           @huntington_bank  @usaa @navyfederalhelp
# 9          marketer struggle                  run me
#
#                      topic2            topic3               topic4  \
# 0                  close on             cheer                   md
# 1                   hell be        cheer loud             union in
# 2                     night         i'm cheer  @navyfederal credit
# 3               in odenton,          loud and      at @navyfederal
# 4                  odenton,         and proud               i'm at
# 5               odenton, md         proud for         credit union
# 6           online banking?              loud                union
# 7              have issues.             proud               credit
# 8  @thaisaidit @navyfederal  @navyfederal i'm           rockville,
# 9               @thaisaidit       midshipmen!        rockville, md
#
#                               topic5                       topic6  \
# 0                  @navyfederal, i'm                      country
# 1                  hey @navyfederal,                    @mflynnjr
# 2                      @navyfederal,                     resource
# 3                                hey             @trumpgirlstrong
# 4                            rooting                   their head
# 5                        i'm rooting                  they should
# 6                        rooting for                      head to
# 7  cards.twitter.com/cards/2egq5x/2…              @basedmonitored
# 8                                i'm  @basedmonitored @rambobiggs
# 9                              navy!          @vfl2013 @jamss3468
#
#                          topic7               topic8            topic9
# 0                       boycott             union in      @navyfederal
# 1                    on hannity  @navyfederal credit  @navyfederalhelp
# 2                  #firehannity         credit union               get
# 3                  @firehannity               i'm at                go
# 4                       hannity                union           deposit
# 5                  because they      at @navyfederal              bank
# 6     @firehannity #firehannity               credit               app
# 7               firehannity.org                   va           account
# 8          boycott @navyfederal             norfolk,             @usaa
# 9  #firehannity firehannity.org          in norfolk,                ??

# %% [markdown]
# Note that some of the above topics represent very standardized social media posts that we can easily filter out with our LDA topic scores:
#
# - topic 1: Go Navy!
# - topic 3: Loud and Proud
# - topic 4: I'm at NFCU in Rockville, MD
# - topic 5: Hey NFCU, I'm Rooting For...
# - topic 7: #FireHannity
# - topic 8: I'm at NFCU in Norfolk, VA
#
# Let's find thresholds that will let us filter those

# %%
def analyze_topic(i, thresholds):
    print("Analyzing topic " + str(i) +"...")
    print("Most common tokens:", lda.topics[i])
    print("Total documents: " + str(len(feature_sets)))
    for t in thresholds:
        print("Number of documents whose topic " + str(i) + " weight is >="+str(t)+" is " + str(len([e for e in feature_sets if e[1][i]>=t])))
        
def filter_features(topic_idx, lower_bound, upper_bound=1, descending=False):
    ret = [e for e in feature_sets if e[1][topic_idx]>=lower_bound and e[1][topic_idx]<=upper_bound]
    ret.sort(key = lambda e: e[1][topic_idx], reverse=descending)
    return ret

# %%
analyze_topic(8, [.3, .4, .5, .6, .7, .8, .9, .95])
# Out:
# Analyzing topic 8...
# Most common tokens: ['union in', '@navyfederal credit', 'credit union', "i'm at", 'union', 'at @navyfederal', 'credit', 'va', 'norfolk,', 'in norfolk,']
# Total documents: 22540
# Number of documents whose topic 8 weight is >=0.3 is 957
# Number of documents whose topic 8 weight is >=0.4 is 621
# Number of documents whose topic 8 weight is >=0.5 is 294
# Number of documents whose topic 8 weight is >=0.6 is 134
# Number of documents whose topic 8 weight is >=0.7 is 41
# Number of documents whose topic 8 weight is >=0.8 is 37
# Number of documents whose topic 8 weight is >=0.9 is 0
# Number of documents whose topic 8 weight is >=0.95 is 0

# %%
f = filter_features(0, .7)
f
# Out:
# [(['navy',
#    'federal',
#    'will\xa0cover\xa0pay',
#    'for\xa0its',
#    'eligible',
#    'members\xa0during',
#    'partial-federal',
#    'government',
#    'shutdown\xa0via',
#    'interest-free',
#    'loans.',
#    'once',
#    'direct',
#    'deposit',
#    'of\xa0pay',
#    'resumes,',
#    'the',
#    'loan',
#    'amount\xa0will\xa0be',
#    'automatically',
#    'deducted',
#    'by\xa0#navyfederal\xa0as',
#    'repayment.\r\nthank',
#    'you',
#    '@navyfederal\r\n#bordersecurity',
#    '@potus'],
#   array([0.71325418, 0.01269978, 0.01269981, 0.01270013, 0.01269978,
#          0.01270012, 0.01269978, 0.01270225, 0.01269978, 0.18514438])),
#  (['@brianbeutler',
#    'between',
#    'this,',
#    'not',
#    'disclosing',
#    'his',
#    'conflicts',
#    'w/cohen',
#    'as',
#    'his',
#    'lawyer',
#    'while',
#    'interviewing',
#    'him,',
#    'causing',
#    'harm',
#    'to',
#    'seth',
#    "rich's",
#    'family',
#    'while',
#    'they',
#    'mourned,',
#    'his',
#    'nightly',
#    'pillow',
#    'talks',
#    'coordination',
#    'w/trump',
#    'while',
#    'playing',
#    'pretend',
#    'journalist...',
#    'non_alpha_numeric',
#    '@foxnews',
#    '#bestpeople',
#    'non_alpha_numeric',
#    '@usaa',
#    '@navyfederal',
#    '????????'],
#   array([0.73437485, 0.01102307, 0.01102284, 0.01102302, 0.01102306,
#          0.01102283, 0.01102318, 0.01102742, 0.01102312, 0.17743661])),
#  (['@wavy_news',
#    'proud',
#    'elite',
#    'force',
#    'honorable',
#    'placement',
#    'tribute',
#    'heritage',
#    'display',
#    'value',
#    '#we',
#    'strive',
#    'not',
#    'all',
#    'achieve',
#    '#ported',
#    '@navyfederal',
#    '@fed_careers'],
#   array([0.74935062, 0.01487679, 0.01487637, 0.02268236, 0.01487804,
#          0.01487643, 0.01487638, 0.0148789 , 0.01487639, 0.12382772])),
#  (['#sdfair',
#    'funds',
#    'non_alpha_numeric',
#    '(at',
#    '@navyfederal',
#    'credit',
#    'union',
#    'non_alpha_numeric',
#    'restricted',
#    'access',
#    'in',
#    'san',
#    'diego,',
#    'ca)',
#    'swarmapp.com/c/bufgwe092wv'],
#   array([0.75858718, 0.01741354, 0.01741356, 0.01741519, 0.0174231 ,
#          0.01741354, 0.01741354, 0.01741357, 0.01743361, 0.10207316])),
#  (['great',
#    '#cx',
#    'in',
#    'banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/hlmzmi9xjx'],
#   array([0.79686511, 0.01463465, 0.01463464, 0.01463825, 0.01463488,
#          0.01463471, 0.0146347 , 0.01463468, 0.08603961, 0.01464877])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/awfwmbt1z7'],
#   array([0.79828618, 0.01460994, 0.01460993, 0.01461352, 0.01461016,
#          0.01460999, 0.01460998, 0.01460996, 0.08481877, 0.01462158])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/bdvbt8f8md'],
#   array([0.79828634, 0.01460994, 0.01460993, 0.01461352, 0.01461016,
#          0.01460999, 0.01460998, 0.01460996, 0.08481861, 0.01462158])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/nxdr7xdimx'],
#   array([0.79828651, 0.01460994, 0.01460993, 0.01461352, 0.01461016,
#          0.01460999, 0.01460998, 0.01460996, 0.08481844, 0.01462158])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/gwoh7ddoel'],
#   array([0.79828652, 0.01460994, 0.01460993, 0.01461352, 0.01461016,
#          0.01460999, 0.01460998, 0.01460996, 0.08481843, 0.01462158])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/blszftq00g'],
#   array([0.79828704, 0.01460994, 0.01460993, 0.01461352, 0.01461016,
#          0.01460999, 0.01460998, 0.01460996, 0.08481791, 0.01462158])),
#  (['great',
#    'cx',
#    'in',
#    'banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/nczqnzauqc'],
#   array([0.86791029, 0.01467475, 0.01467474, 0.01467884, 0.01467499,
#          0.01467479, 0.01467479, 0.01467478, 0.0146752 , 0.01468682])),
#  (['great',
#    'cx',
#    'in',
#    'banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/31rkckvoaz'],
#   array([0.86791029, 0.01467475, 0.01467474, 0.01467884, 0.01467499,
#          0.01467479, 0.01467479, 0.01467478, 0.0146752 , 0.01468682])),
#  (['great',
#    'cx',
#    'in',
#    'banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/ix87daxrqx'],
#   array([0.86791029, 0.01467475, 0.01467474, 0.01467884, 0.01467499,
#          0.01467479, 0.01467479, 0.01467478, 0.0146752 , 0.01468682])),
#  (['great',
#    'cx',
#    'in',
#    'banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/0oulzd1yjk'],
#   array([0.86791029, 0.01467475, 0.01467474, 0.01467884, 0.01467499,
#          0.01467479, 0.01467479, 0.01467478, 0.0146752 , 0.01468682])),
#  (['great',
#    '#cx',
#    'in',
#    'banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/77y8sj0h26'],
#   array([0.86827047, 0.01463465, 0.01463464, 0.01463882, 0.0146349 ,
#          0.0146347 , 0.01463469, 0.01463468, 0.01463511, 0.01464735])),
#  (['great',
#    '#cx',
#    'in',
#    'banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/ab2i35t49n'],
#   array([0.86827047, 0.01463465, 0.01463464, 0.01463882, 0.0146349 ,
#          0.0146347 , 0.01463469, 0.01463468, 0.01463511, 0.01464735])),
#  (['great',
#    '#cx',
#    'in',
#    'banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/qxkobsgtq7'],
#   array([0.86827047, 0.01463465, 0.01463464, 0.01463882, 0.0146349 ,
#          0.0146347 , 0.01463469, 0.01463468, 0.01463511, 0.01464735])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/dhhx57j2yo'],
#   array([0.86847437, 0.01460995, 0.01460994, 0.01461407, 0.0146102 ,
#          0.01460999, 0.01463151, 0.01460998, 0.0146104 , 0.0146196 ])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/uwqgxwc3g3'],
#   array([0.86847452, 0.01460995, 0.01460994, 0.01461407, 0.0146102 ,
#          0.01460999, 0.01463136, 0.01460998, 0.0146104 , 0.0146196 ])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/k1qg5vcazz'],
#   array([0.8684746 , 0.01460995, 0.01460994, 0.01461407, 0.0146102 ,
#          0.01460999, 0.01463128, 0.01460998, 0.0146104 , 0.0146196 ])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/gqord9rntf'],
#   array([0.86847463, 0.01460995, 0.01460994, 0.01461407, 0.0146102 ,
#          0.01460999, 0.01463124, 0.01460998, 0.01461041, 0.01461959])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/m8geprxaiz'],
#   array([0.86847498, 0.01460995, 0.01460994, 0.01461407, 0.0146102 ,
#          0.01460999, 0.0146309 , 0.01460998, 0.0146104 , 0.0146196 ])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/dwzsksdqdq'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/aiwz1q9dv9'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/qjn2uaisjf'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/6xbvs7fzfk'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/nlg755ke41'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/dpjm0uftvb'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/ftg5jxy1k8'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/mkmbpewu9u'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/ovi034dwxc'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/wc7sk72zoe'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/dtote9chde'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/ttgsbundmg'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/eya4pppaxp'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/1swnfpoypo'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087])),
#  (['great',
#    '#cx',
#    'in',
#    '#banking',
#    'is',
#    'rare,',
#    'financial',
#    'marketers',
#    'struggle',
#    'to',
#    'stand',
#    'out',
#    'non_alpha_numeric',
#    'bit.ly/2nlpavi',
#    'non_alpha_numeric',
#    '@forrester',
#    '@navyfederal',
#    '@huntington_bank',
#    '@usaa',
#    '@allybank',
#    'pic.twitter.com/d6rilmmrfk'],
#   array([0.86849474, 0.01460993, 0.01460992, 0.01461406, 0.01461018,
#          0.01460998, 0.01460997, 0.01460996, 0.01461039, 0.01462087]))]

# %%
f[:100]
# Out:
# [(['@navyfederal',
#    'navy',
#    'federal',
#    'has',
#    'the',
#    'worst',
#    'security',
#    'pactices.'],
#   array([0.0222153 , 0.0222153 , 0.0222153 , 0.02221612, 0.0222153 ,
#          0.02221723, 0.0222153 , 0.0222153 , 0.02221531, 0.80005956])),
#  (['shoutout',
#    'to',
#    '@navyfederal',
#    'their',
#    'customer',
#    'service',
#    'is',
#    'a1'],
#   array([0.02217557, 0.02217557, 0.02217557, 0.02217584, 0.02217557,
#          0.02217557, 0.02217559, 0.02217557, 0.02217558, 0.80041958])),
#  (['@navyfederal', 'has', 'now', 'been', 'down', 'over', 'five', 'hours!'],
#   array([0.02211727, 0.02211727, 0.02211727, 0.02211751, 0.02211727,
#          0.02211727, 0.02211727, 0.02211727, 0.02211728, 0.80094432])),
#  (['@urbangem',
#    '@navyfederal',
#    '@usaa',
#    'i',
#    'just',
#    'got',
#    'navy',
#    'federal'],
#   array([0.02211145, 0.0221114 , 0.0221114 , 0.02211171, 0.02211141,
#          0.02211141, 0.02211144, 0.02211141, 0.02211141, 0.80099696])),
#  (['@navyfederalhelp',
#    '',
#    'what',
#    '',
#    'do',
#    'i',
#    'do',
#    'with',
#    '',
#    'the',
#    'app'],
#   array([0.02208791, 0.02208791, 0.02208791, 0.02208853, 0.02208791,
#          0.02208791, 0.02208791, 0.02208791, 0.02208791, 0.80120815])),
#  (['@navyfederal',
#    'i',
#    'would',
#    'love',
#    'to',
#    'know',
#    'what',
#    'you',
#    'are',
#    'doing',
#    'for',
#    'your',
#    'members',
#    'since',
#    'they',
#    'still',
#    "haven't",
#    'received',
#    'a',
#    'response.'],
#   array([0.01467201, 0.01467341, 0.01467262, 0.01467245, 0.08140007,
#          0.01467271, 0.01467478, 0.01467752, 0.0146722 , 0.80121223])),
#  (['@navyfederal',
#    'your',
#    'customer',
#    'service',
#    'is',
#    'literally',
#    'garbage',
#    'xoxo'],
#   array([0.02207906, 0.02207906, 0.02207906, 0.02207931, 0.02207907,
#          0.02207906, 0.02207906, 0.02207906, 0.02207907, 0.80128818])),
#  (['@navyfederalhelp',
#    '',
#    'is',
#    'all',
#    'online',
#    'deposit',
#    'and',
#    'banking',
#    'down?'],
#   array([0.02206985, 0.02206982, 0.02206982, 0.02207069, 0.02206982,
#          0.02206996, 0.02206982, 0.02206982, 0.02206982, 0.80137055])),
#  (['@navyfederalhelp',
#    'can',
#    'you',
#    'just',
#    'dm',
#    'me',
#    'so',
#    'you',
#    'can',
#    'call',
#    'i',
#    "don't",
#    'have',
#    'time',
#    'for',
#    'this'],
#   array([0.01655219, 0.01655197, 0.01655197, 0.01655249, 0.01655197,
#          0.0165533 , 0.01655197, 0.06597847, 0.01655197, 0.80160371])),
#  (['@ohnaira',
#    '@navyfederal',
#    '@navyfederalhelp',
#    'website',
#    'also',
#    'does',
#    'not',
#    'work.'],
#   array([0.02203151, 0.02203151, 0.02203151, 0.02203174, 0.02203151,
#          0.02203151, 0.02203151, 0.02203151, 0.02203152, 0.80171619])),
#  (['@ohnaira',
#    '@navyfederal',
#    '@navyfederalhelp',
#    'website',
#    'also',
#    'does',
#    'not',
#    'work.'],
#   array([0.02203151, 0.02203151, 0.02203151, 0.02203174, 0.02203151,
#          0.02203151, 0.02203151, 0.02203151, 0.02203152, 0.80171619])),
#  (['@navyfederal',
#    'my',
#    'card',
#    'is',
#    'declined',
#    'non_alpha_numeric',
#    'funds',
#    "aren't",
#    'there'],
#   array([0.02202998, 0.02202998, 0.02202998, 0.02203023, 0.02202998,
#          0.02202998, 0.02202998, 0.02202998, 0.02202999, 0.80172992])),
#  (['@navyfederal',
#    'i',
#    'ordered',
#    'a',
#    'new',
#    'credit',
#    'card',
#    'almost',
#    'a',
#    'month',
#    'ago',
#    'and',
#    'still',
#    "haven't",
#    'received',
#    'the',
#    'new',
#    'one',
#    'in',
#    'the',
#    'mail',
#    '??'],
#   array([0.01435278, 0.08343802, 0.01435277, 0.01435331, 0.01435283,
#          0.0143528 , 0.01435277, 0.01435277, 0.01435288, 0.80173909])),
#  (['@navyfederal', 'the', 'app', 'is', 'definitely', 'not', 'working', '??'],
#   array([0.02200907, 0.02200907, 0.02200907, 0.02200998, 0.02200908,
#          0.02200907, 0.02200908, 0.02200907, 0.02200908, 0.80191743])),
#  (['@usaa',
#    'is',
#    'becoming',
#    'spineless.',
#    '',
#    '@navyfederal',
#    '',
#    'what',
#    'say',
#    'you?'],
#   array([0.02197133, 0.0219713 , 0.0219713 , 0.02197152, 0.0219713 ,
#          0.0219713 , 0.02197132, 0.0219713 , 0.02197131, 0.80225803])),
#  (['@navyfederal', 'is', 'there', 'something', 'wrong', 'with', 'the', 'app'],
#   array([0.02195209, 0.02195209, 0.02195208, 0.02195303, 0.02195209,
#          0.02195209, 0.02195209, 0.02195209, 0.0219521 , 0.80243026])),
#  (['@navyfederal',
#    'my',
#    'checking',
#    'and',
#    'savings.',
#    'service',
#    'connected',
#    'disability'],
#   array([0.02189521, 0.02189521, 0.02189521, 0.02189619, 0.02189521,
#          0.02189532, 0.02189521, 0.02189521, 0.02189522, 0.80294201])),
#  (['@navyfederal',
#    'your',
#    'app',
#    'and',
#    'website',
#    "aren't",
#    'working',
#    'again'],
#   array([0.0218948 , 0.0218948 , 0.0218948 , 0.02189599, 0.0218948 ,
#          0.02189494, 0.0218948 , 0.0218948 , 0.02189481, 0.80294546])),
#  (['@navyfederal', 'had', 'the', 'worst', 'customer', 'service', 'ever', '??'],
#   array([0.02188794, 0.02188793, 0.02188793, 0.02188884, 0.02188794,
#          0.02188793, 0.02188793, 0.02188794, 0.02188795, 0.80300767])),
#  (['i', 'swear', '@navyfederal', 'has', 'the', 'best', 'customer', 'service'],
#   array([0.02187695, 0.02187695, 0.02187694, 0.0218779 , 0.02187695,
#          0.02187694, 0.02187695, 0.02187695, 0.02187696, 0.80310651])),
#  (['@navyfederalhelp',
#    'should',
#    'i',
#    'wait',
#    'until',
#    'tomorrow',
#    'to',
#    'call'],
#   array([0.02185954, 0.02185954, 0.02185954, 0.02185954, 0.02185954,
#          0.02186632, 0.02185963, 0.02185954, 0.02185958, 0.80325722])),
#  (['hey',
#    '@navyfederalhelp',
#    '.',
#    'i',
#    'need',
#    'you',
#    'to',
#    'send',
#    'activehours',
#    'my',
#    'updated',
#    'transactions.',
#    'your',
#    'delay',
#    'is',
#    'literally',
#    'costing',
#    'me',
#    'money.',
#    '#paydayrevolution'],
#   array([0.01460337, 0.01460335, 0.01460335, 0.07981863, 0.01460335,
#          0.01461134, 0.01460335, 0.01460335, 0.01460337, 0.80334652])),
#  (['what', 'is', 'going', 'on', 'with', 'direct', 'deposits', '@navyfederal'],
#   array([0.02184973, 0.02184976, 0.02184973, 0.02185006, 0.02184974,
#          0.02184974, 0.02184974, 0.02184976, 0.02184974, 0.80335198])),
#  (['where', 'the', 'fuck', 'my', 'direct', 'deposit', 'at', '@navyfederal'],
#   array([0.02184553, 0.02184553, 0.02184553, 0.02184634, 0.02185085,
#          0.02184553, 0.02184553, 0.02184554, 0.02185684, 0.80337277])),
#  (['@navyfederal', 'why', 'is', 'my', 'app', 'not', 'working', '??'],
#   array([0.02184702, 0.02184702, 0.02184702, 0.02184732, 0.02184703,
#          0.02184702, 0.02184702, 0.02184702, 0.02184703, 0.80337649])),
#  (['@navyfederal',
#    'why',
#    'the',
#    'mobile',
#    'app',
#    'not',
#    'working',
#    '????\u200d♀️'],
#   array([0.02184397, 0.02184397, 0.02184397, 0.02184482, 0.02184398,
#          0.02184397, 0.02184398, 0.02184397, 0.02184398, 0.80340339])),
#  (["i'm",
#    'trying',
#    'to',
#    'make',
#    'my',
#    'money',
#    'work',
#    'better',
#    'and',
#    '@activehours',
#    'is',
#    'helping',
#    'me.',
#    'can',
#    'you',
#    'do',
#    'a',
#    'direct',
#    'connection',
#    'with',
#    'them,',
#    'please?',
#    'non_alpha_numeric',
#    '@navyfederal'],
#   array([0.01392102, 0.01392049, 0.01392049, 0.01392106, 0.01392049,
#          0.08477475, 0.01392052, 0.01392049, 0.01392106, 0.80385963])),
#  (['@navyfederal',
#    '@navyfederalhelp',
#    'why',
#    'is',
#    'the',
#    'app',
#    'not',
#    'working'],
#   array([0.02179282, 0.02179281, 0.02179281, 0.02179397, 0.02179282,
#          0.02179281, 0.02179282, 0.02179281, 0.02179283, 0.80386351])),
#  (['@navyfederal',
#    '@navyfederalhelp',
#    'why',
#    'is',
#    'the',
#    'app',
#    'not',
#    'working'],
#   array([0.02179282, 0.02179281, 0.02179281, 0.02179397, 0.02179282,
#          0.02179281, 0.02179282, 0.02179281, 0.02179283, 0.80386351])),
#  (['@navyfederal', 'when', 'will', 'the', 'app', 'be', 'back', 'up?'],
#   array([0.02178456, 0.02178455, 0.02178455, 0.02178547, 0.02178456,
#          0.02178456, 0.02178455, 0.02178455, 0.02178456, 0.80393808])),
#  (['@navyfederal', 'can', 'i', 'get', 'a', 'new', 'loan', 'processor'],
#   array([0.02178167, 0.02178167, 0.02178167, 0.02178196, 0.02178167,
#          0.02178167, 0.02178167, 0.02178167, 0.02178168, 0.80396469])),
#  (['@navyfederal',
#    'is',
#    'trash.',
#    '@usaa',
#    'is',
#    'the',
#    'bank',
#    'you',
#    'need.'],
#   array([0.02176164, 0.0217616 , 0.0217616 , 0.02176228, 0.0217616 ,
#          0.02176204, 0.0217616 , 0.0217616 , 0.02176161, 0.80414443])),
#  (['@thisbitchtrish',
#    '@navyfederal',
#    'they',
#    'are',
#    'currently',
#    'experiencing',
#    'technical',
#    'issues'],
#   array([0.02176091, 0.02176091, 0.02176091, 0.02176114, 0.02176092,
#          0.02176091, 0.02176092, 0.02176094, 0.02176092, 0.80415151])),
#  (['getting',
#    'my',
#    'debit',
#    'card',
#    'with',
#    'the',
#    'right',
#    'name',
#    'on',
#    'it',
#    'this',
#    'time...',
#    '#namechangesareapain',
#    '(at',
#    '@navyfederal',
#    'credit',
#    'union)',
#    'swarmapp.com/c/kt0d6vplxp3'],
#   array([0.01550597, 0.01550268, 0.01550268, 0.01550288, 0.01550699,
#          0.01550268, 0.01550268, 0.01550269, 0.07169072, 0.80428004])),
#  (['thanks',
#    '@navyfederal',
#    'for',
#    'again',
#    'providing',
#    'excellent',
#    'customer',
#    'service!'],
#   array([0.02173836, 0.02173836, 0.02173836, 0.02173974, 0.02173836,
#          0.02173983, 0.02173836, 0.02173836, 0.02173837, 0.80435191])),
#  (['@navyfederal',
#    "y'all",
#    'garbage.',
#    'im',
#    'glad',
#    "i'm",
#    'switching',
#    'banks.'],
#   array([0.02172247, 0.02172247, 0.02172247, 0.02172572, 0.02172252,
#          0.02172629, 0.02172247, 0.02172249, 0.02172257, 0.80449052])),
#  (['@navyfederal',
#    'my',
#    'daddy',
#    'was',
#    'a',
#    '30',
#    'year',
#    'navy',
#    'veteran.',
#    'go',
#    'navy!'],
#   array([0.01942543, 0.01943219, 0.01942542, 0.01942628, 0.01942543,
#          0.03979465, 0.01942557, 0.01942543, 0.01942543, 0.80479417])),
#  (['@navyfederal', 'could', 'you', 'please', 'fix', 'the', 'mobile', 'app?'],
#   array([0.02168218, 0.02168217, 0.02168217, 0.02168295, 0.02168218,
#          0.02168266, 0.02168217, 0.02168218, 0.02168219, 0.80485915])),
#  (['@ginathesavagee',
#    '@navyfederal',
#    'navy',
#    'fed',
#    'still',
#    'acting',
#    'up',
#    'smh'],
#   array([0.02163796, 0.02163796, 0.02163795, 0.02163818, 0.02163796,
#          0.02163796, 0.02163796, 0.02163796, 0.02163796, 0.80525816])),
#  (['wow',
#    '@navyfederal',
#    'literally',
#    'the',
#    'whole',
#    'day',
#    'i',
#    "haven't",
#    'been',
#    'able',
#    'to',
#    'access',
#    'my',
#    'account.',
#    'i',
#    'will',
#    'be',
#    'finding',
#    'a',
#    'new',
#    'bank',
#    'asap.'],
#   array([0.01415502, 0.01415499, 0.01415946, 0.01415516, 0.0141605 ,
#          0.01415498, 0.01415499, 0.08121705, 0.01415499, 0.80553287])),
#  (['@navyfederal',
#    'do',
#    'we',
#    'know',
#    'when',
#    'they',
#    'will',
#    'be',
#    'an',
#    'eta',
#    'of',
#    'the',
#    'issue',
#    'been',
#    'resolved'],
#   array([0.01669855, 0.01669943, 0.06043362, 0.01669871, 0.01670267,
#          0.01669825, 0.01671203, 0.01670082, 0.01669825, 0.80595769])),
#  (['@navyfederal',
#    "i'm",
#    'about',
#    'to',
#    'fire',
#    'you',
#    'guys',
#    'financially',
#    '??'],
#   array([0.02154811, 0.0215481 , 0.0215481 , 0.02158227, 0.02154816,
#          0.02155235, 0.0215481 , 0.02154812, 0.02155667, 0.80602001])),
#  (['@navyfederal',
#    'i',
#    "can't",
#    'call',
#    'you,',
#    'so',
#    'call',
#    'me',
#    '+81-80-5640-2888'],
#   array([0.02151853, 0.02151853, 0.02151853, 0.02151873, 0.02151853,
#          0.02151852, 0.02151853, 0.02151853, 0.02151853, 0.80633305])),
#  (['@navyfederal',
#    '@navyfederalhelp',
#    'is',
#    'it',
#    'you',
#    'or',
#    'me',
#    '??',
#    'pic.twitter.com/pfzoeef7iw'],
#   array([0.02149147, 0.02149147, 0.02149147, 0.02149169, 0.02149147,
#          0.02149192, 0.02149147, 0.02149147, 0.02149148, 0.8065761 ])),
#  (['@navyfederal',
#    '@navyfederalhelp',
#    'is',
#    'it',
#    'you',
#    'or',
#    'me',
#    '??',
#    'pic.twitter.com/pfzoeef7iw'],
#   array([0.02149147, 0.02149147, 0.02149147, 0.02149169, 0.02149147,
#          0.02149192, 0.02149147, 0.02149147, 0.02149148, 0.8065761 ])),
#  (['annnnnd',
#    'yet',
#    'again',
#    '@navyfederal',
#    'online',
#    'banking',
#    'isnt',
#    'working'],
#   array([0.02148471, 0.02148469, 0.02148932, 0.02148489, 0.02148469,
#          0.02148468, 0.02148469, 0.02148469, 0.02148469, 0.80663296])),
#  (['@cambopicasso',
#    "i'm",
#    'apart',
#    'of',
#    'the',
#    '@navyfederal',
#    'family,',
#    "i'm",
#    'good'],
#   array([0.02147401, 0.02147401, 0.02147401, 0.02147959, 0.02147409,
#          0.02148059, 0.02147401, 0.02147404, 0.02147417, 0.80672149])),
#  (['@navyfederal',
#    '@navyfederalhelp',
#    'i',
#    'swear',
#    'you',
#    'guys',
#    'are',
#    'so',
#    'counter',
#    'productive',
#    'and',
#    'make',
#    'banking',
#    'with',
#    'you',
#    'so',
#    'difficult.',
#    'every',
#    'attempt',
#    'i',
#    'make',
#    'to',
#    'build',
#    'credit',
#    'and',
#    'help',
#    'myself',
#    'you',
#    'guys',
#    'shut',
#    'me',
#    'down.',
#    "it's",
#    'actually',
#    'ridiculous.'],
#   array([0.01188025, 0.01187957, 0.01188276, 0.0118798 , 0.01187942,
#          0.01187959, 0.01187967, 0.09822002, 0.01188428, 0.80673463])),
#  (['@navyfederal',
#    '@navyfederalhelp',
#    'i',
#    'swear',
#    'you',
#    'guys',
#    'are',
#    'so',
#    'counter',
#    'productive',
#    'and',
#    'make',
#    'banking',
#    'with',
#    'you',
#    'so',
#    'difficult.',
#    'every',
#    'attempt',
#    'i',
#    'make',
#    'to',
#    'build',
#    'credit',
#    'and',
#    'help',
#    'myself',
#    'you',
#    'guys',
#    'shut',
#    'me',
#    'down.',
#    "it's",
#    'actually',
#    'ridiculous.'],
#   array([0.01188025, 0.01187957, 0.01188276, 0.0118798 , 0.01187942,
#          0.01187959, 0.01187967, 0.09822002, 0.01188428, 0.80673463])),
#  (['shout',
#    'to',
#    '@navyfederal',
#    'for',
#    'alerting',
#    'me',
#    'to',
#    'fraud',
#    'on',
#    'my',
#    'account',
#    'this',
#    'morning.',
#    'they',
#    'are',
#    'the',
#    'best!'],
#   array([0.01619621, 0.0161962 , 0.0161962 , 0.01619697, 0.0161962 ,
#          0.0161968 , 0.01619621, 0.06329486, 0.01619621, 0.80713414])),
#  (['@emtlove16',
#    '@navyfederal',
#    'sarah,',
#    'what',
#    'happened?',
#    "we'd",
#    'like',
#    'to',
#    'learn',
#    'more',
#    'so',
#    'we',
#    'can',
#    'address',
#    'any',
#    'issues.'],
#   array([0.01604597, 0.01604597, 0.01604597, 0.01604604, 0.01604598,
#          0.06441324, 0.01604603, 0.01604597, 0.01604598, 0.80721883])),
#  (['@navyfederal',
#    'when',
#    'are',
#    'you',
#    'going',
#    'to',
#    'fix',
#    'direct',
#    'deposit???'],
#   array([0.0213717 , 0.02137172, 0.0213717 , 0.02137195, 0.0213717 ,
#          0.02137214, 0.02137171, 0.0213717 , 0.02137171, 0.80765397])),
#  (['@navyfederal',
#    'is',
#    'abt',
#    'the',
#    'service',
#    'to',
#    'its',
#    'members',
#    'twitter.com/veteran4trump/…'],
#   array([0.02134163, 0.02134162, 0.02134168, 0.02134221, 0.02134163,
#          0.02134162, 0.02134162, 0.02134162, 0.02134163, 0.80792473])),
#  (['@navyfederalhelp',
#    'thanks!',
#    'non_alpha_numeric',
#    'navy',
#    'federal',
#    'is',
#    'the',
#    'a',
#    'best',
#    '??'],
#   array([0.02133619, 0.02133619, 0.02133619, 0.02133661, 0.02133619,
#          0.0213362 , 0.02133619, 0.02133619, 0.02133619, 0.80797388])),
#  (['@darthnirraw',
#    '@michellerawlngs',
#    '@navyfederal',
#    'debit',
#    'cards',
#    "ain't",
#    'working,',
#    'tho.'],
#   array([0.02132867, 0.02132864, 0.02132864, 0.02132883, 0.02132865,
#          0.02132864, 0.02132864, 0.02132864, 0.02132865, 0.80804199])),
#  (['i',
#    'seriously',
#    'love',
#    '@navyfederal',
#    'i',
#    'lost',
#    'my',
#    'debit',
#    'card',
#    'and',
#    'within',
#    'the',
#    'hour',
#    'i',
#    'was',
#    'able',
#    'to',
#    'go',
#    'to',
#    'a',
#    'branch',
#    'and',
#    'get',
#    'a',
#    'new',
#    'one',
#    'issued',
#    'in',
#    '5',
#    'minutes.'],
#   array([0.01260264, 0.09104421, 0.01260527, 0.01260307, 0.01260265,
#          0.01260306, 0.01260264, 0.01260263, 0.01260266, 0.80813118])),
#  (['@theplayoffguru',
#    '@pacificmarinecu',
#    '@bofa_help',
#    '@navyfederal',
#    'is',
#    'the',
#    'superior',
#    'credit',
#    'union'],
#   array([0.02131654, 0.02131652, 0.02131652, 0.02131705, 0.02131736,
#          0.02131652, 0.02131741, 0.02131652, 0.02131813, 0.80814741])),
#  (['@d0ccupcake',
#    '@navyfederal',
#    '@navyfederalhelp',
#    '@pncbank',
#    'is',
#    'the',
#    'way',
#    'to',
#    'go.'],
#   array([0.02128671, 0.02128671, 0.0212867 , 0.02128735, 0.02128671,
#          0.02128671, 0.02128671, 0.02128671, 0.02128672, 0.80841899])),
#  (['@d0ccupcake',
#    '@navyfederal',
#    '@navyfederalhelp',
#    '@pncbank',
#    'is',
#    'the',
#    'way',
#    'to',
#    'go.'],
#   array([0.02128671, 0.02128671, 0.0212867 , 0.02128735, 0.02128671,
#          0.02128671, 0.02128671, 0.02128671, 0.02128672, 0.80841899])),
#  (['why',
#    'is',
#    '@zelle',
#    'so',
#    'slow',
#    'on',
#    '@navyfederal',
#    '@navyfederalhelp',
#    '??'],
#   array([0.02121346, 0.02121338, 0.02121338, 0.02121359, 0.02121339,
#          0.02121339, 0.02121338, 0.02121341, 0.02121339, 0.80907922])),
#  (['why',
#    'is',
#    '@zelle',
#    'so',
#    'slow',
#    'on',
#    '@navyfederal',
#    '@navyfederalhelp',
#    '??'],
#   array([0.02121346, 0.02121338, 0.02121338, 0.02121359, 0.02121339,
#          0.02121339, 0.02121338, 0.02121341, 0.02121339, 0.80907922])),
#  (['@navyfederal',
#    '@navyfederalhelp',
#    'is',
#    'your',
#    'app',
#    'ever',
#    'going',
#    'to',
#    'work?'],
#   array([0.02120334, 0.02120336, 0.02120334, 0.0212036 , 0.02120334,
#          0.02120335, 0.02120335, 0.02120334, 0.02120335, 0.80916963])),
#  (['@navyfederal',
#    '@navyfederalhelp',
#    'is',
#    'your',
#    'app',
#    'ever',
#    'going',
#    'to',
#    'work?'],
#   array([0.02120334, 0.02120336, 0.02120334, 0.0212036 , 0.02120334,
#          0.02120335, 0.02120335, 0.02120334, 0.02120335, 0.80916963])),
#  (['i',
#    'love',
#    'my',
#    'bank,',
#    '@navyfederal',
#    '@navyfederalhelp',
#    'your',
#    'the',
#    'best.'],
#   array([0.02118176, 0.02118176, 0.02118176, 0.02118243, 0.02118176,
#          0.02118176, 0.02118176, 0.02118176, 0.02118177, 0.80936348])),
#  (['i',
#    'love',
#    'my',
#    'bank,',
#    '@navyfederal',
#    '@navyfederalhelp',
#    'your',
#    'the',
#    'best.'],
#   array([0.02118176, 0.02118176, 0.02118176, 0.02118243, 0.02118176,
#          0.02118176, 0.02118176, 0.02118176, 0.02118177, 0.80936348])),
#  (['why',
#    'is',
#    'your',
#    'refi',
#    'process',
#    'so',
#    'slow?',
#    '@navyfederal',
#    '@navyfederalhelp'],
#   array([0.02117109, 0.02117109, 0.02117109, 0.02117129, 0.02117109,
#          0.02117109, 0.02117109, 0.02117109, 0.0211711 , 0.80945998])),
#  (['why',
#    'is',
#    'your',
#    'refi',
#    'process',
#    'so',
#    'slow?',
#    '@navyfederal',
#    '@navyfederalhelp'],
#   array([0.02117109, 0.02117109, 0.02117109, 0.02117129, 0.02117109,
#          0.02117109, 0.02117109, 0.02117109, 0.0211711 , 0.80945998])),
#  (['@navyfederal',
#    'why',
#    'is',
#    'it',
#    'that',
#    'deposits',
#    'have',
#    'completely',
#    'disappeared'],
#   array([0.0211177 , 0.0211177 , 0.0211177 , 0.02111792, 0.02111771,
#          0.02111772, 0.0211177 , 0.0211177 , 0.02111771, 0.80994044])),
#  (['today', 'is', 'not', 'the', 'day', 'to', 'play', '@navyfederal', '??'],
#   array([0.02110186, 0.02110185, 0.02110185, 0.02110256, 0.02110186,
#          0.02110185, 0.02110186, 0.02110185, 0.02110186, 0.8100826 ])),
#  (['@navyfederal',
#    'if',
#    'i',
#    'still',
#    "haven't",
#    'received',
#    'my',
#    'new',
#    'chip',
#    'card',
#    'that',
#    'was',
#    'sent',
#    'a',
#    'month',
#    'ago',
#    'who',
#    'should',
#    'i',
#    'get',
#    'in',
#    'contact',
#    'with?'],
#   array([0.01380612, 0.01380611, 0.01380611, 0.01380616, 0.01380613,
#          0.0138078 , 0.07934228, 0.01380611, 0.01380617, 0.810207  ])),
#  (['the',
#    '@navyfederal',
#    'app',
#    'is',
#    'useless',
#    '...',
#    'it',
#    'never',
#    'works'],
#   array([0.02106009, 0.02106008, 0.02106008, 0.02106073, 0.02106009,
#          0.0210601 , 0.02106008, 0.02106008, 0.02106009, 0.81045857])),
#  (['ohkay',
#    '@navyfederal',
#    'why',
#    'is',
#    'your',
#    'atm',
#    'not',
#    'working',
#    '??'],
#   array([0.02104197, 0.02104091, 0.02104091, 0.02104113, 0.02104092,
#          0.02104092, 0.02104092, 0.02104092, 0.02104092, 0.81063047])),
#  (['@bluesea1964',
#    '@junogsp7',
#    'go',
#    'to',
#    '@navyfederal',
#    '.',
#    'they',
#    'love',
#    'veterans'],
#   array([0.02100401, 0.02100402, 0.021004  , 0.0210042 , 0.02100401,
#          0.02100401, 0.02100402, 0.02100403, 0.02100401, 0.81096368])),
#  (['@navyfederal',
#    'both',
#    'representatives',
#    'i',
#    'spoke',
#    'with',
#    'were',
#    'helpful.',
#    '??'],
#   array([0.02099936, 0.02099936, 0.02099936, 0.02099954, 0.02099936,
#          0.02099936, 0.02099936, 0.02099936, 0.02099936, 0.81100559])),
#  (['@navyfederal', 'has', 'to', 'be', 'the', 'worst', 'bank', 'ever', '??'],
#   array([0.02097163, 0.02097162, 0.02097162, 0.02097248, 0.02097163,
#          0.02097163, 0.02097163, 0.02097163, 0.02097164, 0.81125449])),
#  (['@navyfederalhelp',
#    'hey',
#    'can',
#    'you',
#    'update',
#    'the',
#    'system',
#    'mannnnnnn',
#    'hahaha'],
#   array([0.02096144, 0.02096144, 0.02096144, 0.02096179, 0.02096144,
#          0.02098814, 0.02096144, 0.02096144, 0.02096144, 0.81131998])),
#  (['i',
#    'love',
#    '@navyfederal',
#    'never',
#    'will',
#    'i',
#    'bank',
#    'anywhere',
#    'else.'],
#   array([0.02096209, 0.02096209, 0.02096209, 0.02096229, 0.02096209,
#          0.02096209, 0.02096209, 0.02096209, 0.0209621 , 0.81134097])),
#  (['@navyfederal',
#    'so',
#    'is',
#    'everything',
#    'back',
#    'up',
#    'and',
#    'running',
#    '?'],
#   array([0.02095349, 0.02095349, 0.02095349, 0.02095448, 0.02095349,
#          0.02095361, 0.02095349, 0.02095349, 0.0209535 , 0.81141748])),
#  (['@navyfederal',
#    'why',
#    'is',
#    'the',
#    'mobile',
#    'app',
#    'always',
#    'down',
#    'sheesh'],
#   array([0.02094109, 0.02094109, 0.02094109, 0.0209418 , 0.02094109,
#          0.02094109, 0.02094109, 0.02094109, 0.0209411 , 0.81152947])),
#  (['@navyfederal',
#    "that's",
#    'why',
#    "it's",
#    'been',
#    'my',
#    'bank',
#    'since',
#    '1982.'],
#   array([0.02094046, 0.02094046, 0.02094046, 0.02094068, 0.02094047,
#          0.02094046, 0.02094046, 0.02094046, 0.02094048, 0.81153561])),
#  (['@mjurosky',
#    '@navyfederal',
#    '...now',
#    'i',
#    'know',
#    'why',
#    'they',
#    'lost.',
#    '??'],
#   array([0.02093607, 0.02093607, 0.02093607, 0.02093624, 0.02093607,
#          0.02093606, 0.02093607, 0.02093609, 0.02093607, 0.8115752 ])),
#  (['@navyfederal',
#    'mobile',
#    'app',
#    'is',
#    'really',
#    'upsetting',
#    'me',
#    'today',
#    '??'],
#   array([0.0209247 , 0.0209247 , 0.0209247 , 0.0209249 , 0.0209247 ,
#          0.0209247 , 0.0209247 , 0.0209247 , 0.02092471, 0.81167749])),
#  (['@navyfederalhelp',
#    'i',
#    'am',
#    'having',
#    'trouble',
#    'logging',
#    'into',
#    'the',
#    'mobile',
#    'app.',
#    'is',
#    'the',
#    'app',
#    'down',
#    'right',
#    'now?'],
#   array([0.01627103, 0.01628113, 0.05810914, 0.01627139, 0.01627102,
#          0.01627103, 0.01627102, 0.01627102, 0.01627165, 0.81171157])),
#  (['@navyfederal',
#    'i',
#    'want',
#    'to',
#    'know',
#    'why',
#    'i',
#    'have',
#    'money',
#    'in',
#    'my',
#    'account',
#    'but',
#    'my',
#    'card',
#    "isn't",
#    'working.'],
#   array([0.01596961, 0.0159672 , 0.01597237, 0.01596729, 0.01596723,
#          0.01596719, 0.01596852, 0.0159679 , 0.06049721, 0.81175547])),
#  (['just',
#    'signed',
#    'up',
#    'for',
#    'a',
#    '@navyfederal',
#    'bank',
#    'account',
#    '??'],
#   array([0.02089981, 0.02089981, 0.02089981, 0.02090125, 0.02089981,
#          0.02090133, 0.02089981, 0.02089981, 0.02089982, 0.81189873])),
#  (['spooky',
#    'tales',
#    'from',
#    'a',
#    'navy',
#    'federal',
#    'branch',
#    '@navyfederal',
#    'ow.ly/bivc50eqvs2'],
#   array([0.0208946 , 0.0208946 , 0.0208946 , 0.02089479, 0.0208946 ,
#          0.0208946 , 0.0208946 , 0.0208946 , 0.0208946 , 0.81194842])),
#  (['shout',
#    'out',
#    'to',
#    '@navyfederal',
#    "they're",
#    'always',
#    'so',
#    'helpful!!!',
#    '??'],
#   array([0.0208705 , 0.02087042, 0.02087042, 0.02087062, 0.02087043,
#          0.02087042, 0.02087043, 0.02087043, 0.02087043, 0.81216589])),
#  (['@navyfederal',
#    '@navyfederalhelp',
#    "i'll",
#    'call',
#    'to',
#    'close',
#    'it.',
#    '',
#    'thanks.',
#    'non_alpha_numeric',
#    ')'],
#   array([0.02085611, 0.02085611, 0.02085611, 0.0208563 , 0.02085611,
#          0.02085611, 0.02085611, 0.02085611, 0.02085612, 0.81229483])),
#  (['@navyfederal',
#    '@navyfederalhelp',
#    "i'll",
#    'call',
#    'to',
#    'close',
#    'it.',
#    '',
#    'thanks.',
#    'non_alpha_numeric',
#    ')'],
#   array([0.02085611, 0.02085611, 0.02085611, 0.0208563 , 0.02085611,
#          0.02085611, 0.02085611, 0.02085611, 0.02085612, 0.81229483])),
#  (['so',
#    "what's",
#    'up',
#    'with',
#    'navy',
#    'federal',
#    'tonight?',
#    '??',
#    '@navyfederal'],
#   array([0.02085241, 0.02085241, 0.02085241, 0.02085263, 0.02085241,
#          0.02085241, 0.02085241, 0.02085241, 0.02085242, 0.81232808])),
#  (['worse',
#    'bank',
#    'since',
#    "i've",
#    'been',
#    'using',
#    'it',
#    'smh',
#    '@navyfederal'],
#   array([0.02084777, 0.02084777, 0.02084777, 0.02084798, 0.02084777,
#          0.02084779, 0.02084777, 0.02084777, 0.02084778, 0.81236983])),
#  (['@navyfederal',
#    'app',
#    "isn't",
#    'working',
#    'and',
#    "it's",
#    'stressing',
#    'me',
#    'out.'],
#   array([0.02083777, 0.02083777, 0.02083777, 0.02083869, 0.02083777,
#          0.02083788, 0.02083777, 0.02083777, 0.02083778, 0.81245904])),
#  (['@navyfederal',
#    'i',
#    'need',
#    'my',
#    'money',
#    'and',
#    'i',
#    'need',
#    'it',
#    'now',
#    '@navyfederal'],
#   array([0.0208338 , 0.0208338 , 0.0208338 , 0.02083531, 0.02083381,
#          0.02083394, 0.0208338 , 0.0208338 , 0.02083381, 0.81249415])),
#  (['@navyfederal',
#    "y'all",
#    'have',
#    'to',
#    'be',
#    'the',
#    'worst',
#    'bank',
#    'ever'],
#   array([0.02083045, 0.02083044, 0.02083044, 0.02083129, 0.02083045,
#          0.02083044, 0.02083044, 0.02083044, 0.02083046, 0.81252513])),
#  (["can't",
#    'make',
#    'deposits',
#    'at',
#    'hinesville',
#    'atm',
#    'again',
#    '@navyfederal',
#    '@navyfederalhelp'],
#   array([0.02081655, 0.02081655, 0.02081655, 0.02081675, 0.02081672,
#          0.02081655, 0.02081657, 0.02081655, 0.02081682, 0.81265037])),
#  (["can't",
#    'make',
#    'deposits',
#    'at',
#    'hinesville',
#    'atm',
#    'again',
#    '@navyfederal',
#    '@navyfederalhelp'],
#   array([0.02081655, 0.02081655, 0.02081655, 0.02081675, 0.02081672,
#          0.02081655, 0.02081657, 0.02081655, 0.02081682, 0.81265037])),
#  (['@navyfederal', 'you', 'guys', 'need', 'to', 'fix', 'the', 'app', '??'],
#   array([0.02078146, 0.02078146, 0.02078146, 0.02078228, 0.02078147,
#          0.02078196, 0.02078146, 0.02078146, 0.02078147, 0.81296552])),
#  (['lmaoooo',
#    'nobody',
#    'has',
#    'better',
#    'customer',
#    'service',
#    'than',
#    '@navyfederal',
#    'perioddddt'],
#   array([0.02077326, 0.02077326, 0.02077326, 0.02077343, 0.02077326,
#          0.02077326, 0.02077326, 0.02077326, 0.02077326, 0.8130405 ])),
#  (['@navyfederal',
#    "can't",
#    'find',
#    'any',
#    'near',
#    'me',
#    'navy',
#    'federal',
#    'locations.'],
#   array([0.02076843, 0.02076843, 0.02076843, 0.02076863, 0.02076843,
#          0.02076843, 0.02076843, 0.02076843, 0.02076843, 0.81308395])),
#  (['@navyfederal', 'and', 'i', "don't", 'have', 'the', 'mobile', 'app', '??'],
#   array([0.0207307 , 0.0207307 , 0.0207307 , 0.02073245, 0.0207307 ,
#          0.02073085, 0.0207307 , 0.0207307 , 0.02073071, 0.81342182]))]
